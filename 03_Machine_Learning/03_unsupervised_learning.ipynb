# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanasri02/ai-ml-learning-journey/blob/main/03_Machine_Learning/03_unsupervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unsupervised Learning
#
# ## Overview
# Unsupervised learning works with **unlabeled data**.
# The goal is to discover hidden patterns or structures in data
# without predefined output labels.

# %% [markdown]
# ## What is Unsupervised Learning?
# Unsupervised learning identifies patterns, similarities,
# or groupings in data without knowing the correct output in advance.
# ## What is Unsupervised Learning?
# Unsupervised learning identifies patterns, similarities,
# or groupings in data without knowing the correct output in advance.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ## K-Means Clustering
# K-Means groups data points into K clusters
# based on similarity.

# %%
# Sample data
X = np.array([
    [1, 2],
    [1, 4],
    [1, 0],
    [10, 2],
    [10, 4],
    [10, 0]
])

#Train KMeans model
KMeans = KMeans(n_clusters=2, random_state=42)
KMeans.fit(X)

#Cluster Labels
labels = KMeans.labels_
print("Cluster labels:", labels)
# Out:
# Cluster labels: [0 0 0 1 1 1]

# %%
plt.scatter(X[:,0], X[:, 1], c = labels)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# ## Dimensionality Reduction
# ## Principal Component Analysis (PCA)
# PCA reduces the number of features while preserving
# as much information as possible.

# %%
# Create sample data
X = np.random.rand(100, 3)

#Apply PCA
pca = PCA(n_components=2)
X_reduced =pca.fit_transform(X)

print("Original Shape:", X.shape)
print("Reduced Shape:",X_reduced.shape)
# Out:
# Original Shape: (100, 3)
# Reduced Shape: (100, 2)

# %% [markdown]
# ## Key Takeaways
# - Unsupervised learning works without labels
# - Clustering finds natural groupings
# - PCA reduces dimensionality
# - Useful for EDA and feature engineering
