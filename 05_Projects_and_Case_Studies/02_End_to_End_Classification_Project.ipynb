# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanasri02/ai-ml-learning-journey/blob/main/05_Projects_and_Case_Studies/02_End_to_End_Classification_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # End-to-End Classification Project
#
# ## Problem Statement
# Predict whether a student will pass or fail
# based on study hours.

# %%
# 1. Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
# 2. Create dataset
data = {
    "study_hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "pass": [0, 0, 0, 0, 1, 1, 1, 1]
}

df = pd.DataFrame(data)
df

# 3. Features and Target
X = df[["study_hours"]]
y = df["pass"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

#Safety checks
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

# 5. Train Model
model = LogisticRegression()
model.fit(X_train, y_train)

# 6. Predict
y_pred = model.predict(X_test)

# 7. Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[1 0]
#  [0 1]]
