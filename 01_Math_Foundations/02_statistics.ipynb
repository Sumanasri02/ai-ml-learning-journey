# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanasri02/ai-ml-learning-journey/blob/main/01_Math_Foundations/02_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistics for Machine Learning
#
# ## Overview
# Statistics is essential to understand data distributions, trends, and patterns.
# This notebook covers **basic statistics concepts** used in ML, including mean, variance, standard deviation, and correlation.
# All examples use Python and NumPy for practical understanding.

# %%
import numpy as np

# %% [markdown]
# ## Mean, Median, Mode
# - **Mean**: Average of numbers
# - **Median**: Middle value when sorted
# - **Mode**: Most frequent value

# %%
data = [10, 20, 20, 30, 40, 50, 50, 50]
#mean
mean = np.mean(data)
print("Mean:", mean)

#Median
median = np.median(data)
print("Median:", median)

#Mode
from scipy import stats
mode_result = stats.mode(data, keepdims=True)
mode = mode_result.mode[0]
print("Mode:", mode)
# Out:
# Mean: 33.75
# Median: 35.0
# Mode: 50

# %% [markdown]
# ## Variance and Standard Deviation
# - **Variance** measures the spread of data
# - **Standard Deviation (Std Dev)** is the square root of variance

# %%
# Variance
variance = np.var(data)
print("Variance:", variance)

# Standard Deviation
std_dev = np.std(data)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 223.4375
# Standard Deviation: 14.947825928876748

# %% [markdown]
# ## Correlation
# - Measures how two variables are related
# - Value ranges from -1 to 1
#   - 1 → perfectly positive correlation
#   - -1 → perfectly negative correlation
#   - 0 → no correlation

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

correlation = np.corrcoef(x,y)[0,1]
print("Correlation between x and y:", correlation)
# Out:
# Correlation between x and y: 0.7745966692414834

# %% [markdown]
# ## Key Takeaways
# - Mean, Median, Mode summarize central tendency
# - Variance and Standard Deviation measure spread
# - Correlation shows relationship between variables
# - Understanding statistics is crucial for ML model insights

# %%
from google.colab import drive
drive.mount('/content/drive')
